# %% [markdown]
# # Project Title : Student Performance dataset (EDA)
# ## Quantitative
# ## A quantitative variable is a variable that reflects a notion of magnitude, that is, if the values it can take are numbers. A quantitative variable represents thus a measure and is numerical.
#
# ## Quantitative variables are divided into two types: discrete and continuous. The difference is explained in the following two sections.
#
# ## Discrete
# ## Quantitative discrete variables are variables for which the values it can take are countable and have a finite number of possibilities. The values are often (but not always) integers. Here are some examples of discrete variables:
#
# ## Continuous
# ## On the other hand, quantitative continuous variables are variables for which the values are not countable and have an infinite number of possibilities. For example: Age,Weight,Height
#
# ## Qualitative
# ## In opposition to quantitative variables, qualitative variables (also referred as categorical variables or factors in R) are variables that are not numerical and which values fits into categories.
#
# ## In other words, a qualitative variable is a variable which takes as its values modalities, categories or even levels, in contrast to quantitative variables which measure a quantity on each individual.
#
# ## Qualitative variables are divided into two types: nominal and ordinal.
# ## Nominal
# ## A qualitative nominal variable is a qualitative variable where no ordering is possible or implied in the levels.
#
# ## For example, the variable gender is nominal because there is no order in the levels (no matter how many levels you consider for the gender—only two with female/male, or more than two with female/male/ungendered/others, levels are unordered). Eye color is another example of a nominal variable because there is no order among blue, brown or green eyes.
#
# ## Ordinal
# ## On the other hand, a qualitative ordinal variable is a qualitative variable with an order implied in the levels. For instance, if the severity of road accidents has been measured on a scale such as light, moderate and fatal accidents, this variable is a qualitative ordinal variable because there is a clear order in the levels.
#
# ## Another good example is health, which can take values such as poor, reasonable, good, or excellent. Again, there is a clear order in these levels so health is in this case a qualitative ordinal variable
#
# ## Nominal :
# 1. gender
# ## Ordinal :
# 2. parental level of education
# 3. lunch
# 4. test preparation course
# 5. race/ethnicity
# ## DISCRETE:
# 6. math score
# 7. reading score
# 8. writing score

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sns.boxplot(df['math score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='math score'>

# %%
q1=df['math score'].quantile(0.25)

# %%
q3=df['math score'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['math score']>lower) & (df['math score']<upper)]

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(df['math score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='math score'>

# %%
sns.boxplot(df['reading score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='reading score'>

# %%
q1=df['reading score'].quantile(0.25)

# %%
q3=df['reading score'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['reading score']>lower) & (df['reading score']<upper)]

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(df['reading score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='reading score'>

# %%
sns.boxplot(df['writing score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='writing score'>

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.distplot(df['math score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='math score', ylabel='Density'>

# %%
sns.distplot(df['reading score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='reading score', ylabel='Density'>

# %%
sns.distplot(df['writing score'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='writing score', ylabel='Density'>

# %% [markdown]
# # Feature Enginerring

# %%
df['Total Score']=df['math score']+df['reading score']+df['writing score']
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_12464\2562162943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Score']=df['math score']+df['reading score']+df['writing score']

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df['Average']=round((df['Total Score']/3),2)
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_12464\3531476357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average']=round((df['Total Score']/3),2)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sns.countplot(df['lunch'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
total_lunch_df=df.groupby("lunch").size()

# %%
plt.pie(x=total_lunch_df.values,labels=total_lunch_df.index,autopct="%1.2f%%")
plt.show()

# %%
sns.countplot(x='lunch',hue='gender',data=df)
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
sns.countplot(x='lunch',hue='test preparation course',data=df)
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %% [markdown]
# # Compare avg Score for Male and Female

# %%
total_Score_df=df.groupby("gender")['Total Score'].mean()

# %%
plt.pie(x=total_Score_df.values,labels=total_Score_df.index,autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=total_Score_df.index,y=total_Score_df.values)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='parental level of education',data=df)
plt.show()

# %%
parental_level_of_education_df=df.groupby("parental level of education").size()

# %%
plt.pie(x=parental_level_of_education_df.values,labels=parental_level_of_education_df.index,autopct="%1.2f%%")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='test preparation course',data=df)
plt.show()

# %%
test_preparation_course_df=df.groupby("test preparation course").size()

# %%
plt.pie(x=test_preparation_course_df.values,labels=test_preparation_course_df.index,autopct="%1.2f%%")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='test preparation course',hue='gender',data=df)
plt.show()

# %%
test_preparation_course_gender_df=df.groupby("test preparation course")['gender'].size()

# %%
plt.pie(x=test_preparation_course_gender_df.values,labels=test_preparation_course_gender_df.index,autopct="%1.2f%%")
plt.show()

# %%
sns.countplot(df['race/ethnicity'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
total_race_ethnicity_df=df.groupby("race/ethnicity").size()

# %%
plt.pie(x=total_race_ethnicity_df.values,labels=total_race_ethnicity_df.index,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Comapre test preparation course and Total Score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
label_df=df.groupby("test preparation course")['Total Score'].mean().index

# %%
val_df=df.groupby("test preparation course")['Total Score'].mean().values

# %%
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observation
# 1. Students who have completed test preparation course got more marks compared to other students who have not taken course

# %%
sns.barplot(x=label_df,y=val_df,data=df)
# Out:
# <AxesSubplot:xlabel='test preparation course'>

# %% [markdown]
# # Compare parental level of education	and total score

# %%
label_degree_df=df.groupby("parental level of education")['Total Score'].mean().index

# %%
val_degree_df=df.groupby("parental level of education")['Total Score'].mean().values

# %%
plt.pie(x=val_degree_df,labels=label_degree_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observation
# 1. Students whoes parents have master's degree got maximum marks as compared to students with different parental level of education.
# 2. Students whoes parents have 	high school got minimum marks as compared to students with different parental level of education.

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_degree_df,y=val_degree_df)
plt.show()

# %% [markdown]
# # Compare race/ethnicity with math score,reading score and writing score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
math_score_df=df.groupby("race/ethnicity")['math score'].sum()
reading_score_df=df.groupby("race/ethnicity")['reading score'].sum()
writing_score_df=df.groupby("race/ethnicity")['writing score'].sum()

# %%
label_df=math_score_df.index
val_df=math_score_df.values

# %%
val_df
# Out:
# array([ 5457, 11898, 20451, 17596, 10305], dtype=int64)

# %% [markdown]
# # Comparing Math Score for different race/ethnicity group

# %%
sns.barplot(x=label_df,y=val_df)
plt.show()

# %%
label_df=reading_score_df.index
val_df=reading_score_df.values

# %% [markdown]
# # Comparing reading Score for different race/ethnicity group

# %%
sns.barplot(x=label_df,y=val_df)
plt.show()

# %%
label_df=writing_score_df.index
val_df=writing_score_df.values

# %% [markdown]
# # Comparing writing Score for different race/ethnicity group

# %%
sns.barplot(x=label_df,y=val_df)
plt.show()

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Comparing gender and lunch with total Score.

# %%
total_Score_df=df.groupby(['gender','lunch'])['Total Score'].mean()

# %%
total_Score_df.index
# Out:
# MultiIndex([('female', 'free/reduced'),
#             ('female',     'standard'),
#             (  'male', 'free/reduced'),
#             (  'male',     'standard')],
#            names=['gender', 'lunch'])

# %%
total_Score_df.values
# Out:
# array([194.52486188, 220.4617737 , 186.2173913 , 205.47301587])

# %%
plt.pie(x=total_Score_df.values,labels=total_Score_df.index,autopct="%12.f%%")
plt.show()

# %%
total_Score_df=df.groupby(['gender','lunch'])['Total Score']

# %%
sns.barplot(x='lunch',y='Total Score',data=df,hue='gender')
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='Total Score'>

# %% [markdown]
# # Comparing gender and lunch with writing score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
label_df=df.groupby(['gender','lunch'])['writing score'].mean().index

# %%
val_df=df.groupby(['gender','lunch'])['writing score'].mean().values

# %%
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Comparing gender and math score

# %%
math_avg_score_val_df=df.groupby("gender")['math score'].mean().values
math_avg_score_label_df=df.groupby("gender")['math score'].mean().index

# %%
math_avg_score_val_df
# Out:
# array([64.5       , 69.20378151])

# %%
plt.pie(x=math_avg_score_val_df,labels=math_avg_score_label_df,autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=math_avg_score_label_df,y=math_avg_score_val_df)
# Out:
# <AxesSubplot:xlabel='gender'>

# %% [markdown]
# # Comparing gender and reading score

# %%
reading_avg_score_df=df.groupby("gender")['reading score'].mean().index
reading_avg_score_val_df=df.groupby("gender")['reading score'].mean().values

# %%
reading_avg_score_df
# Out:
# Index(['female', 'male'], dtype='object', name='gender')

# %%
reading_avg_score_val_df
# Out:
# array([73.39566929, 65.95378151])

# %%
plt.pie(x=reading_avg_score_val_df,labels=reading_avg_score_df,autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=reading_avg_score_df,y=reading_avg_score_val_df)
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Comparing gender and writing score

# %%
writing_avg_score_label_df=df.groupby("gender")['writing score'].mean().index
writing_avg_score_val_df=df.groupby("gender")['writing score'].mean().values

# %%
writing_avg_score_label_df
# Out:
# Index(['female', 'male'], dtype='object', name='gender')

# %%
writing_avg_score_val_df
# Out:
# array([73.32480315, 63.80252101])

# %%
plt.pie(x=writing_avg_score_val_df,labels=writing_avg_score_label_df,autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=writing_avg_score_label_df,y=writing_avg_score_val_df)
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.barplot (x=df['lunch'], y=df['math score'], hue=df['test preparation course'])
plt.subplot(2,2,2)
sns.barplot (x=df['lunch'], y=df['reading score'], hue=df['test preparation course'])
plt.subplot(2,2,3)
sns.barplot (x=df['lunch'], y=df['writing score'], hue=df['test preparation course'])
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='writing score'>

# %%
sns.pairplot(data=df,hue='gender')

# %% [markdown]
# # From the above plot it is clear that all the scores increase linearly with each other.

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sns.boxplot(x='gender',y='Total Score',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Total Score'>

# %%
sns.boxplot(x='gender',y='Total Score',hue='lunch',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Total Score'>

# %%
sns.boxplot(x='gender',y='Total Score',hue='test preparation course',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='parental level of education',y='Total Score',data=df)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='test preparation course',y='Total Score',data=df)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='test preparation course',y='Total Score',data=df,hue='lunch')
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='parental level of education',y='Total Score',data=df,hue='gender')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='Total Score'>

# %%
sns.boxplot(x='lunch',y='Total Score',data=df)
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='test preparation course',y='Total Score',data=df,hue='gender')
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='gender',y='math score',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='gender',y='reading score',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='reading score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='gender',y='writing score',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='writing score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='race/ethnicity',y='Total Score',data=df)
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='race/ethnicity',y='Total Score',data=df,hue='gender')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='Total Score'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='race/ethnicity',y='Total Score',data=df,hue='test preparation course')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='Total Score'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
